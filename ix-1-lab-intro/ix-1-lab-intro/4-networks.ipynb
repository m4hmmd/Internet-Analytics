# %% [markdown]
# # Networks
#
# In this last exercise, you will start to put into practice some of the concepts learned in class. Start by importing the libraries that you will need.

# %%
import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# We give you the network of the 34 members of [karate clubs](https://en.wikipedia.org/wiki/Zachary's_karate_club) on the campus. Each node is a member of one of two clubs ("Mr. Hi" or "Officer") and there is an edge between two nodes if the two are friends outside of the club.

# %%
karate_club = nx.karate_club_graph()

# %% [markdown]
# ## Visualization
#
# 1. Visualize the network by
#     - painting every 'Mr. Hi' member in **blue** and every 'Officer' member in **red**, and
#     - drawing the label corresponding to the member index (between 1 and 34) on each node.
# 2. What can you tell about the nodes and their connections? Do you see some nodes with more/less links than others? Who can they be?

# %%
# Your code goes here
# print(karate_club)
mr_hi = [i for i in range(34) if karate_club.node[i]['club']=='Mr. Hi']
officer = [i for i in range(34) if karate_club.node[i]['club']=='Officer']

plt.figure(figsize=(15, 10))

sp = nx.circular_layout(karate_club)
nx.draw_networkx_nodes(karate_club, pos=sp, nodelist=mr_hi, node_color='b')
nx.draw_networkx_nodes(karate_club, pos=sp, nodelist=officer, node_color='r')

nx.draw_networkx_edges(karate_club, sp)
nx.draw_networkx_labels(karate_club, sp)
# Out:
# {0: Text(1,5.20087e-09,'0'),
#  1: Text(0.982973,0.18375,'1'),
#  2: Text(0.932472,0.361242,'2'),
#  3: Text(0.850217,0.526432,'3'),
#  4: Text(0.739009,0.673696,'4'),
#  5: Text(0.602635,0.798017,'5'),
#  6: Text(0.445738,0.895163,'6'),
#  7: Text(0.273663,0.961826,'7'),
#  8: Text(0.0922684,0.995734,'8'),
#  9: Text(-0.0922683,0.995734,'9'),
#  10: Text(-0.273663,0.961826,'10'),
#  11: Text(-0.445738,0.895163,'11'),
#  12: Text(-0.602635,0.798017,'12'),
#  13: Text(-0.739009,0.673696,'13'),
#  14: Text(-0.850217,0.526432,'14'),
#  15: Text(-0.932472,0.361242,'15'),
#  16: Text(-0.982973,0.18375,'16'),
#  17: Text(-1,-8.22219e-08,'17'),
#  18: Text(-0.982973,-0.183749,'18'),
#  19: Text(-0.932472,-0.361242,'19'),
#  20: Text(-0.850217,-0.526432,'20'),
#  21: Text(-0.739009,-0.673696,'21'),
#  22: Text(-0.602635,-0.798017,'22'),
#  23: Text(-0.445738,-0.895163,'23'),
#  24: Text(-0.273663,-0.961826,'24'),
#  25: Text(-0.0922682,-0.995734,'25'),
#  26: Text(0.0922682,-0.995734,'26'),
#  27: Text(0.273663,-0.961826,'27'),
#  28: Text(0.445738,-0.895163,'28'),
#  29: Text(0.602635,-0.798017,'29'),
#  30: Text(0.739009,-0.673696,'30'),
#  31: Text(0.850217,-0.526432,'31'),
#  32: Text(0.932472,-0.361242,'32'),
#  33: Text(0.982973,-0.183749,'33')}

# %% [markdown]
# ## Degree Distribution
#
# 1. Plot the degree distribution of the network.
# 2. Does it confirm your answer to the previous question?

# %%
# Your code goes here
# plt.figure(figsize=(15, 10))
y = [karate_club.degree[i] for i in range(34)]
plt.plot(y, 'bo')
plt.grid(True)
